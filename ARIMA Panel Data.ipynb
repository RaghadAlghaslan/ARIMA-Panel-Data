# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error
from pmdarima.arima import auto_arima
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import warnings
# Suppress all warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel("date_temp.xlsx")

# %% [markdown]
# # Preprocessing

# %% [markdown]
# In the case of the dataset that I have, there is two columns that specify the panels in my data, which are 'assetnum' and 'location' and they are associated to each other, so I need to combine these two columns into one column to use it later as my panel ID

# %%
# Create a new column called 'time_series_id' by combining 'assetnum' and 'location' values
df['time_series_id'] = df['assetnum'] + '_' + df['location']

# %%
# Drop columns
columns_to_drop = ['assetnum', 'location', 'Temperature']
df = df.drop(columns=columns_to_drop)

# %%
# Define the desired column order
column_order = ['time_series_id', 'month', 'reading']
# Reorder the columns
df = df.reindex(columns=column_order)

# %% [markdown]
# Renaming the column to an easier name

# %%
df = df.rename(columns={'time_series_id': 'unique_id'})

# %%
train = df.loc[df['month'] < '2023-12-01']
test = df.loc[(df['month'] >= '2023-12-01')]
h = test['month'].nunique()

# %% [markdown]
# # Model

# %% [markdown]
# In the model stage, I am going to search for the best order of ARIMA (p,d,q) for each panel in the dataset, and printout the best oreder alonside the performance metrics, then fit the model for the panel using the best order found by the search, lastly printing out the average of the performance metrics for all of the panels to evaluate the model performance on the whole dataset in general.

# %%
# Define a function to evaluate the ARIMA model for each panel
def evaluate_panel_arima_model(panel_data_train, panel_data_test, order):
    model = ARIMA(panel_data_train['reading'], order=order)
    model_fit = model.fit()
    predictions = model_fit.predict(start=len(panel_data_train), end=len(panel_data_train) + len(panel_data_test) - 1)
    mse = mean_squared_error(panel_data_test['reading'], predictions)
    rmse = np.sqrt(mse)
    r2 = r2_score(panel_data_test['reading'], predictions)
    mape = mean_absolute_percentage_error(panel_data_test['reading'], predictions)
    return mse, rmse, r2, mape, predictions

# %%
# Define the range of parameters to search over
p_values = range(0, 4)  # Example range for p (AR)
d_values = range(0, 4)  # Example range for d (I)
q_values = range(0, 4)  # Example range for q (MA)

# %%
# Create a list of unique panel IDs
panel_ids = train['unique_id'].unique()

# %%
# Create empty lists to store the best orders and performance metrics for each panel
best_orders = []
mse_scores = []
rmse_scores = []
r2_scores = []
mape_scores = []

# Loop over all possible combinations of parameters and select the best one for each panel
for panel_id in panel_ids:
    panel_data_train = train[train['unique_id'] == panel_id]
    panel_data_test = test[test['unique_id'] == panel_id]

    best_mse = float('inf')
    best_order = None

    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p, d, q)
                try:
                    mse, _, _, _, _ = evaluate_panel_arima_model(panel_data_train, panel_data_test, order)
                    if mse < best_mse:
                        best_mse = mse
                        best_order = order
                except:
                    continue

    # Append the best order to the list
    best_orders.append(best_order)

    # Print the best order
    print("Best Order:", best_order)
    
    # Fit the ARIMA model using the best order for the current panel
    model = ARIMA(panel_data_train['reading'], order=best_order)
    model_fit = model.fit()

    # Generate predictions for the test set of the current panel
    predictions = model_fit.predict(start=len(panel_data_train), end=len(panel_data_train) + len(panel_data_test) - 1)

    # Evaluate the model's performance on the test set of the current panel
    mse = mean_squared_error(panel_data_test['reading'], predictions)
    rmse = np.sqrt(mse)
    r2 = r2_score(panel_data_test['reading'], predictions)
    mape = mean_absolute_percentage_error(panel_data_test['reading'], predictions)

    # Append the performance metrics to the respective lists
    mse_scores.append(mse)
    rmse_scores.append(rmse)
    r2_scores.append(r2)
    mape_scores.append(mape)

    # Print the evaluation metrics for the current panel
    print("Evaluation Metrics - Panel ID: {}".format(panel_id))
    print("MSE:", mse)
    print("RMSE:", rmse)
    print("R^2:", r2)
    print("MAPE:", mape)
    print("------------------------")
# Out:
# Best Order: (0, 1, 0)
# Evaluation Metrics - Panel ID: AS000302_07-790-GF-0100
# MSE: 0.0
# RMSE: 0.0
# R^2: 1.0
# MAPE: 0.0
# ------------------------
# Best Order: (2, 1, 0)
# Evaluation Metrics - Panel ID: AS001653_07-916-Z11-SEC03
# MSE: 1.442939067735537e+17
# RMSE: 379860377.99901384
# R^2: -0.00501517303424337
# MAPE: 1.3699080533972383
# ------------------------
# Best Order: (2, 2, 2)
# Evaluation Metrics - Panel ID: AS001654_07-916-Z17-SEC02
# MSE: 56707295871.244446
# RMSE: 238132.93739263463
# R^2: 0.9652340426032601
# MAPE: 0.002456953613427926
# ------------------------
# Best Order: (0, 1, 0)
# Evaluation Metrics - Panel ID: AS001655_07-8124-GF
# MSE: 34086010467855.332
# RMSE: 5838322.573124521
# R^2: -0.5181314252793652
# MAPE: 0.14948070342151398
# ------------------------
# Best Order: (1, 1, 1)
# Evaluation Metrics - Panel ID: AS001656_07-8125-GF
# MSE: 118377277076960.55
# RMSE: 10880132.217806939
# R^2: -59.87986271010644
# MAPE: 0.18598947439090355
# ------------------------
# Best Order: (3, 2, 2)
# Evaluation Metrics - Panel ID: AS001657_07-8126-GF
# MSE: 821651149203.5775
# RMSE: 906449.7499605687
# R^2: 0.16768113437918608
# MAPE: 0.006835567483727043
# ------------------------
# Best Order: (0, 1, 0)
# Evaluation Metrics - Panel ID: AS001658_07-8030-F-F3
# MSE: 0.0
# RMSE: 0.0
# R^2: 1.0
# MAPE: 0.0
# ------------------------
# Best Order: (0, 2, 0)
# Evaluation Metrics - Panel ID: AS001659_07-916-Z11-SEC08
# MSE: 226628648935.06125
# RMSE: 476055.3002909024
# R^2: 0.6290202224901352
# MAPE: 0.004100147012718658
# ------------------------
# Best Order: (3, 2, 2)
# Evaluation Metrics - Panel ID: AS001660_07-8122-GF
# MSE: 92597253574.73555
# RMSE: 304297.9684038912
# R^2: 0.7380838086873218
# MAPE: 0.002095204808758953
# ------------------------
# Best Order: (3, 2, 2)
# Evaluation Metrics - Panel ID: AS001662_07-916-Z14-SEC07
# MSE: 30595229029.736614
# RMSE: 174914.91940293892
# R^2: 0.7112631522480312
# MAPE: 0.0021480645781594434
# ------------------------
# Best Order: (2, 2, 2)
# Evaluation Metrics - Panel ID: AS001663_07-916-Z14-SEC15
# MSE: 122844820611.24841
# RMSE: 350492.25470935646
# R^2: 0.8213635919717044
# MAPE: 0.002111186983792889
# ------------------------
# Best Order: (3, 3, 2)
# Evaluation Metrics - Panel ID: AS001664_07-916-Z15-SEC05
# MSE: 109890009117766.64
# RMSE: 10482843.560683649
# R^2: -71.02408113469629
# MAPE: 0.1531722541959559
# ------------------------
# Best Order: (2, 2, 2)
# Evaluation Metrics - Panel ID: AS001731_07-916-Z11-SEC01
# MSE: 300151609124.7133
# RMSE: 547860.939586601
# R^2: 0.6378043769414162
# MAPE: 0.007163548635089595
# ------------------------
# Best Order: (0, 2, 0)
# Evaluation Metrics - Panel ID: AS002478_07-8123-GF
# MSE: 534352064507.0
# RMSE: 730993.8881461322
# R^2: 0.39315156565593856
# MAPE: 0.021157895855033693
# ------------------------
# Best Order: (0, 1, 0)
# Evaluation Metrics - Panel ID: AS002761_07-770-GF-0506
# MSE: 0.0
# RMSE: 0.0
# R^2: 1.0
# MAPE: 0.0
# ------------------------
# Best Order: (1, 2, 0)
# Evaluation Metrics - Panel ID: AS002762_07-770-GF-0106
# MSE: 491162388476.54376
# RMSE: 700829.7856659231
# R^2: -2.2733738042838514
# MAPE: 0.11117858089405223
# ------------------------
# Best Order: (3, 2, 2)
# Evaluation Metrics - Panel ID: AS002763_07-770-GF-0501
# MSE: 1253032743376.9365
# RMSE: 1119389.451163864
# R^2: -0.6306167073825601
# MAPE: 0.02856154180208693
# ------------------------
# Best Order: (1, 1, 0)
# Evaluation Metrics - Panel ID: AS002764_07-770-GF-0406
# MSE: 3043068226813.4043
# RMSE: 1744439.2298997992
# R^2: -1.092262864765147
# MAPE: 0.03468384894509032
# ------------------------
# Best Order: (3, 1, 2)
# Evaluation Metrics - Panel ID: AS002765_07-770-GF-0406
# MSE: 310117281352.0808
# RMSE: 556881.7480866838
# R^2: -3.354988133371413
# MAPE: 0.011120254433906166
# ------------------------
# Best Order: (1, 1, 0)
# Evaluation Metrics - Panel ID: AS002768_07-770-GF-0106
# MSE: 38645566.527583346
# RMSE: 6216.555841266396
# R^2: -1.2745044928415559
# MAPE: 0.00010959272478921903
# ------------------------
# Best Order: (3, 2, 2)
# Evaluation Metrics - Panel ID: AS003270_07-8121-GF
# MSE: 180753282781.7307
# RMSE: 425150.8941325782
# R^2: 0.6819332227921782
# MAPE: 0.003845203523239619
# ------------------------
# Best Order: (0, 0, 0)
# Evaluation Metrics - Panel ID: AS005062_07-770-GF-0706
# MSE: 4.604316927725449e-12
# RMSE: 2.1457672119140625e-06
# R^2: 0.0
# MAPE: 1.785066881929805e-15
# ------------------------
# Best Order: (1, 1, 0)
# Evaluation Metrics - Panel ID: AS005063_07-770-GF-0706
# MSE: 1404601045777.2852
# RMSE: 1185158.6584830256
# R^2: -82.31367425514568
# MAPE: 0.027149753282135522
# ------------------------
# Best Order: (1, 1, 0)
# Evaluation Metrics - Panel ID: AS005064_07-770-GF-0701
# MSE: 176516365474.2925
# RMSE: 420138.5074880575
# R^2: -7.086074174075087
# MAPE: 0.004308243316763686
# ------------------------
# Best Order: (0, 2, 2)
# Evaluation Metrics - Panel ID: AS005065_07-770-GF-0701
# MSE: 690116955347969.0
# RMSE: 26270077.18580151
# R^2: -607.7240279492908
# MAPE: 9.208949635071361
# ------------------------
# Best Order: (2, 1, 0)
# Evaluation Metrics - Panel ID: AS005066_07-770-GF-0206
# MSE: 1.2918589195794802e+16
# RMSE: 113659971.82735355
# R^2: 0.047944228362011065
# MAPE: 0.834102220993216
# ------------------------
# Best Order: (3, 1, 2)
# Evaluation Metrics - Panel ID: AS005067_07-770-GF-0206
# MSE: 1199631902691.415
# RMSE: 1095277.0894579212
# R^2: -49.16487387248147
# MAPE: 0.015528826011118895
# ------------------------
# Best Order: (0, 1, 0)
# Evaluation Metrics - Panel ID: AS005068_07-770-GF-0201
# MSE: 0.0
# RMSE: 0.0
# R^2: 1.0
# MAPE: 0.0
# ------------------------
# Best Order: (2, 1, 2)
# Evaluation Metrics - Panel ID: AS005069_07-770-GF-0506
# MSE: 212385903079557.28
# RMSE: 14573465.719572585
# R^2: 0.8245755051017702
# MAPE: 0.45636997451010636
# ------------------------
# Best Order: (0, 1, 0)
# Evaluation Metrics - Panel ID: AS01880_07-916-Z11-SEC01
# MSE: 1472824674078.0
# RMSE: 1213599.8822008842
# R^2: -6.162074264697068
# MAPE: 0.00812373040340336
# ------------------------
# Best Order: (0, 2, 0)
# Evaluation Metrics - Panel ID: AS021946_07-8121-GF
# MSE: 651603185.973989
# RMSE: 25526.519268674077
# R^2: 0.36922310699884364
# MAPE: 0.00024085883398578076
# ------------------------
# Best Order: (2, 3, 2)
# Evaluation Metrics - Panel ID: AS059037_05-112-B-100608
# MSE: 0.09868081057081168
# RMSE: 0.31413501965048674
# R^2: 0.5559363524313474
# MAPE: 0.00015442355694329478
# ------------------------
# Best Order: (2, 3, 2)
# Evaluation Metrics - Panel ID: AS059038_05-112-B-100608
# MSE: 0.09868081057025137
# RMSE: 0.3141350196495949
# R^2: 0.5559363524338687
# MAPE: 6.322180209939375e-05
# ------------------------
# Best Order: (3, 1, 0)
# Evaluation Metrics - Panel ID: AS059039_05-121-B
# MSE: 351237.8394915049
# RMSE: 592.6532202658692
# R^2: -0.12517243913069231
# MAPE: 0.12227720864207965
# ------------------------
# Best Order: (3, 3, 1)
# Evaluation Metrics - Panel ID: AS059040_05-121-B
# MSE: 104087.52985237946
# RMSE: 322.62599066470057
# R^2: -0.1274618642255041
# MAPE: 0.030763143420990725
# ------------------------
# Best Order: (2, 1, 0)
# Evaluation Metrics - Panel ID: AS059041_05-121-B
# MSE: 640371.646069859
# RMSE: 800.2322450825504
# R^2: -0.3523583505724772
# MAPE: 0.09589974891833881
# ------------------------
# Best Order: (2, 2, 3)
# Evaluation Metrics - Panel ID: AS059045_02-260-B-100606
# MSE: 257810.81455927016
# RMSE: 507.7507405797358
# R^2: 0.625202390931253
# MAPE: 0.06729476755932452
# ------------------------
# Best Order: (2, 3, 0)
# Evaluation Metrics - Panel ID: AS059047_02-260-B-100606
# MSE: 0.346365671508998
# RMSE: 0.5885283948196536
# R^2: 0.7181472835821963
# MAPE: 0.0002701695498981753
# ------------------------
# Best Order: (0, 3, 2)
# Evaluation Metrics - Panel ID: AS059048_02-250-B-100631
# MSE: 1396.051346643282
# RMSE: 37.36377050892056
# R^2: 0.5914261797675098
# MAPE: 1.6002051641499733
# ------------------------
# Best Order: (3, 3, 1)
# Evaluation Metrics - Panel ID: AS059049_02-250-B-100631
# MSE: 10187.244056054753
# RMSE: 100.93187829449501
# R^2: -0.3839692746119545
# MAPE: 0.31691709156546205
# ------------------------
# Best Order: (2, 1, 3)
# Evaluation Metrics - Panel ID: AS059050_02-250-B-100631
# MSE: 631056.7543870074
# RMSE: 794.3908070886819
# R^2: 0.3985710599716974
# MAPE: 0.03978342280275051
# ------------------------
# Best Order: (1, 2, 0)
# Evaluation Metrics - Panel ID: AS059052_02-240-SCHNRS-B-100605
# MSE: 2482358.808032422
# RMSE: 1575.550319105176
# R^2: -0.20484450531585008
# MAPE: 0.15283352288077837
# ------------------------
# Best Order: (1, 3, 1)
# Evaluation Metrics - Panel ID: AS059053_02-240-SCHNRS-B-100605
# MSE: 16933.40517209571
# RMSE: 130.12841800350802
# R^2: -0.16910948563283656
# MAPE: 0.16132579660776655
# ------------------------
# Best Order: (3, 0, 3)
# Evaluation Metrics - Panel ID: AS059054_02-220-SCHBS-B-100606
# MSE: 0.33768838788679956
# RMSE: 0.5811096177889328
# R^2: 0.16620151139050598
# MAPE: 0.0001015165007898503
# ------------------------
# Best Order: (1, 1, 1)
# Evaluation Metrics - Panel ID: AS059055_02-220-SCHBS-B-100606
# MSE: 0.12840028266610762
# RMSE: 0.3583298517652522
# R^2: 0.18666296099156865
# MAPE: 0.0003613061499671304
# ------------------------
# Best Order: (0, 3, 2)
# Evaluation Metrics - Panel ID: AS059056_02-230-B-100612
# MSE: 10750.99080773571
# RMSE: 103.68698475573349
# R^2: 0.4099114522351204
# MAPE: 0.11658936946510712
# ------------------------
# Best Order: (0, 1, 0)
# Evaluation Metrics - Panel ID: AS059058_02-210-B-1006072
# MSE: 0.0
# RMSE: 0.0
# R^2: 1.0
# MAPE: 0.0
# ------------------------
# Best Order: (2, 1, 3)
# Evaluation Metrics - Panel ID: AS059060_02-410-B-100609
# MSE: 35684.50986708121
# RMSE: 188.90344059090404
# R^2: 0.4619191622418215
# MAPE: 1.1386406033507197
# ------------------------
# Best Order: (1, 0, 3)
# Evaluation Metrics - Panel ID: AS059061_02-410-B-100609
# MSE: 0.050259359031010364
# RMSE: 0.22418599204903586
# R^2: 0.1642785565283026
# MAPE: 0.0003097997675304111
# ------------------------
# Best Order: (0, 3, 2)
# Evaluation Metrics - Panel ID: AS059062_02-410-B-100632
# MSE: 0.03256633521975217
# RMSE: 0.180461450785901
# R^2: 0.5436205617998182
# MAPE: 0.0009062744394376104
# ------------------------
# Best Order: (3, 2, 1)
# Evaluation Metrics - Panel ID: AS070526_07-7110-B-100608
# MSE: 5.105961590820068e+16
# RMSE: 225963749.10193157
# R^2: 0.013284739986746175
# MAPE: 1.0184203715857378
# ------------------------
# Best Order: (3, 2, 2)
# Evaluation Metrics - Panel ID: AS070605_07-770-GF-0106
# MSE: 110911486617.72894
# RMSE: 333033.76197876537
# R^2: 0.6179330657175539
# MAPE: 0.0035296895955940328
# ------------------------
# Best Order: (0, 1, 0)
# Evaluation Metrics - Panel ID: AS071097_1921359
# MSE: 0.0
# RMSE: 0.0
# R^2: 1.0
# MAPE: 0.0
# ------------------------
# Best Order: (0, 1, 0)
# Evaluation Metrics - Panel ID: AS071099_1921359
# MSE: 0.0
# RMSE: 0.0
# R^2: 1.0
# MAPE: 0.0
# ------------------------
# Best Order: (0, 1, 0)
# Evaluation Metrics - Panel ID: AS071102_1921359
# MSE: 0.0
# RMSE: 0.0
# R^2: 1.0
# MAPE: 0.0
# ------------------------
# Best Order: (3, 3, 2)
# Evaluation Metrics - Panel ID: AS073265_07-7110-B-100608
# MSE: 2880768177611.464
# RMSE: 1697282.5862570629
# R^2: -82.52859231944957
# MAPE: 0.03708839411343409
# ------------------------
# Best Order: (3, 2, 2)
# Evaluation Metrics - Panel ID: AS338275_03-310-B-100634
# MSE: 44540397057.17382
# RMSE: 211045.95958504826
# R^2: 0.9036705447580904
# MAPE: 0.0029846876253560722
# ------------------------
# Best Order: (0, 1, 0)
# Evaluation Metrics - Panel ID: AS340499_02-250-B
# MSE: 0.0
# RMSE: 0.0
# R^2: 1.0
# MAPE: 0.0
# ------------------------
# Best Order: (3, 3, 0)
# Evaluation Metrics - Panel ID: AS340512_05-122-B
# MSE: 30831.46019105383
# RMSE: 175.58889540928786
# R^2: 0.7683076253154645
# MAPE: 0.0747168659173411
# ------------------------
# Best Order: (0, 0, 0)
# Evaluation Metrics - Panel ID: AS340513_05-122-B
# MSE: 0.07259491900619862
# RMSE: 0.26943444287284174
# R^2: -0.500048071279432
# MAPE: 8.279033228842299e-05
# ------------------------
# Best Order: (1, 0, 2)
# Evaluation Metrics - Panel ID: AS340524_02-240-SCHNRS-B
# MSE: 6714697.30767274
# RMSE: 2591.2732985296516
# R^2: 0.5134828542690827
# MAPE: 0.2363722125272256
# ------------------------
# Best Order: (3, 0, 1)
# Evaluation Metrics - Panel ID: AS340528_02-230-B
# MSE: 10928.293049503947
# RMSE: 104.53847640703373
# R^2: -0.22943296806919422
# MAPE: 0.10772263585088483
# ------------------------
# Best Order: (1, 3, 0)
# Evaluation Metrics - Panel ID: AS340541_05-122-B
# MSE: 160.49966785401054
# RMSE: 12.66884635055657
# R^2: 0.8180275874671082
# MAPE: 0.0012433420578472061
# ------------------------
# Best Order: (1, 0, 2)
# Evaluation Metrics - Panel ID: AS340542_05-122-B
# MSE: 1008.1766787692392
# RMSE: 31.751798039941598
# R^2: -0.2771933286962076
# MAPE: 0.002455971432186572
# ------------------------
# Best Order: (3, 0, 2)
# Evaluation Metrics - Panel ID: AS340543_02-410-B
# MSE: 0.986736712908226
# RMSE: 0.9933462200603704
# R^2: 0.1101572729284529
# MAPE: 0.006870054332069764
# ------------------------
# Best Order: (3, 0, 2)
# Evaluation Metrics - Panel ID: AS340544_02-410-B
# MSE: 1.2967732965573695
# RMSE: 1.1387595429050725
# R^2: 0.13291532919641158
# MAPE: 0.008456560505621708
# ------------------------
# Best Order: (2, 0, 1)
# Evaluation Metrics - Panel ID: AS340545_02-410-B
# MSE: 354.17356536146536
# RMSE: 18.81949960443862
# R^2: 0.3715583691947102
# MAPE: 0.23163677300502275
# ------------------------
# Best Order: (2, 1, 3)
# Evaluation Metrics - Panel ID: AS340551_02-240-SCHNRS-B
# MSE: 1217.525957821039
# RMSE: 34.89306460918901
# R^2: -0.15078067846979093
# MAPE: 0.0839342552895954
# ------------------------
# Best Order: (0, 3, 2)
# Evaluation Metrics - Panel ID: AS340553_02-230-B
# MSE: 30025.176548966014
# RMSE: 173.27774395162817
# R^2: 0.1010026179950817
# MAPE: 0.2634503844216623
# ------------------------
# Best Order: (2, 0, 1)
# Evaluation Metrics - Panel ID: AS340558_02-210-B
# MSE: 472.9222035519988
# RMSE: 21.74677455513803
# R^2: -0.49998819358255275
# MAPE: 0.11111479694143779
# ------------------------
# Best Order: (0, 1, 0)
# Evaluation Metrics - Panel ID: AS340593_02-210-B
# MSE: 0.0
# RMSE: 0.0
# R^2: 1.0
# MAPE: 0.0
# ------------------------
# Best Order: (1, 1, 1)
# Evaluation Metrics - Panel ID: AS343477_05-111-B-100620
# MSE: 68052.72754844355
# RMSE: 260.869177076257
# R^2: 0.21393781024656588
# MAPE: 0.01208211317015608
# ------------------------
# Best Order: (0, 0, 2)
# Evaluation Metrics - Panel ID: AS343478_05-111-B-100620
# MSE: 18093.847338970274
# RMSE: 134.51337234256778
# R^2: 0.21076556653241352
# MAPE: 0.008984563754177983
# ------------------------
# Best Order: (1, 3, 1)
# Evaluation Metrics - Panel ID: AS343483_05-111-B-100620
# MSE: 18881.079227298964
# RMSE: 137.40843943258713
# R^2: 0.021462873526555737
# MAPE: 0.01238060624093545
# ------------------------
# Best Order: (2, 3, 3)
# Evaluation Metrics - Panel ID: AS343625_05-112-B-100608
# MSE: 0.10485921808250892
# RMSE: 0.32381973084188204
# R^2: 0.520034093963577
# MAPE: 1.1036399600413137e-05
# ------------------------
# Best Order: (1, 3, 3)
# Evaluation Metrics - Panel ID: AS360103_02-210-B-1006072
# MSE: 1.1907573822861357
# RMSE: 1.0912183018471306
# R^2: -0.05845100647656509
# MAPE: 0.007401002365907328
# ------------------------
# Best Order: (2, 2, 3)
# Evaluation Metrics - Panel ID: AS360410_02-230-B-100612
# MSE: 289132.280086892
# RMSE: 537.710219436912
# R^2: 0.014116525267423241
# MAPE: 0.6493813404179525
# ------------------------
# Best Order: (1, 1, 1)
# Evaluation Metrics - Panel ID: AS360679_02-250-B-100608
# MSE: 628125.8111968891
# RMSE: 792.5438859753377
# R^2: 0.07147684212492511
# MAPE: 0.1690417932924065
# ------------------------
# Best Order: (2, 0, 2)
# Evaluation Metrics - Panel ID: AS360700_02-250-B-100631
# MSE: 21565.678165023426
# RMSE: 146.85257289207917
# R^2: 0.12260170397238845
# MAPE: 0.5235747041540781
# ------------------------
# Best Order: (1, 0, 0)
# Evaluation Metrics - Panel ID: AS360701_02-250-B-100631
# MSE: 174854.25285142544
# RMSE: 418.15577581976004
# R^2: 0.010717995322224283
# MAPE: 1.755962733976941
# ------------------------
# Best Order: (1, 0, 3)
# Evaluation Metrics - Panel ID: AS360727_02-250-B-100631
# MSE: 208011.1337701277
# RMSE: 456.08237607928646
# R^2: 0.44965768893000024
# MAPE: 0.09382317801494067
# ------------------------
# Best Order: (1, 3, 1)
# Evaluation Metrics - Panel ID: AS360987_02-410-B-100609
# MSE: 1.3396055771527482
# RMSE: 1.1574133130186244
# R^2: 0.08071290931187836
# MAPE: 0.007130426832229881
# ------------------------
# Best Order: (0, 2, 0)
# Evaluation Metrics - Panel ID: AS361897_07-770-1F-100606
# MSE: 1490707630688.6667
# RMSE: 1220945.383990892
# R^2: -4.073116357038058
# MAPE: 0.013786057905903376
# ------------------------

# %%
# Calculate the average performance metrics for all panels
avg_mse = np.mean(mse_scores)
avg_rmse = np.mean(rmse_scores)
avg_r2 = np.mean(r2_scores)
avg_mape = np.mean(mape_scores)

# Print the average performance metrics
print("Average Performance Metrics:")
print("Average MSE:", avg_mse)
print("Average RMSE:", avg_rmse)
print("Average R^2:", avg_r2)
print("Average MAPE:", avg_mape)
# Out:
# Average Performance Metrics:
# Average MSE: 2523532685533975.5
# Average RMSE: 9677400.778356532
# Average R^2: -11.491001975969136
# Average MAPE: 0.264328038702531
